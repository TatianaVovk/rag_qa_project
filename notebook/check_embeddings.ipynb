# %%
import numpy as np
import json

# Пути
emb_path = "C:/Users/User/Desktop/Партфолио/rag_qa_project/vector_db/embeddings/chunk_embeddings.npy"
ids_path = "C:/Users/User/Desktop/Партфолио/rag_qa_project/vector_db/embeddings/chunk_ids.json"

# Загрузка
embeddings = np.load(emb_path)
with open(ids_path, encoding="utf-8") as f:
    ids = json.load(f)

# Проверки
print(f"✅ Размерность эмбеддингов: {embeddings.shape}")
print(f"✅ Количество ID: {len(ids)}")

assert embeddings.shape[0] == len(ids), "❌ Несовпадение количества эмбеддингов и ID"
# Out:
# ✅ Размерность эмбеддингов: (56333, 768)
# ✅ Количество ID: 56333
